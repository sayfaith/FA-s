# %%
#1

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#2

df = pd.read_csv('./Spotify_Youtube.csv')

df.head(10)
# Out:
#    Unnamed: 0    Artist                                        Url_spotify  \
# 0           0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1           1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2           2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3           3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4           4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 5           5  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 6           6  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 7           7  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 8           8  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 9           9  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                                Track  \
# 0                                     Feel Good Inc.
# ...

# %%
#3

df.columns
# Out:
# Index(['Unnamed: 0', 'Artist', 'Url_spotify', 'Track', 'Album', 'Album_type',
#        'Uri', 'Danceability', 'Energy', 'Key', 'Loudness', 'Speechiness',
#        'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo',
#        'Duration_ms', 'Url_youtube', 'Title', 'Channel', 'Views', 'Likes',
#        'Comments', 'Description', 'Licensed', 'official_video', 'Stream'],
#       dtype='object')

# %%
#4

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20718 entries, 0 to 20717
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        20718 non-null  int64
#  1   Artist            20718 non-null  object
#  2   Url_spotify       20718 non-null  object
#  3   Track             20718 non-null  object
#  4   Album             20718 non-null  object
#  5   Album_type        20718 non-null  object
#  6   Uri               20718 non-null  object
#  7   Danceability      20716 non-null  float64
#  8   Energy            20716 non-null  float64
#  9   Key               20716 non-null  float64
#  10  Loudness          20716 non-null  float64
#  11  Speechiness       20716 non-null  float64
#  12  Acousticness      20716 non-null  float64
#  13  Instrumentalness  20716 non-null  float64
#  14  Liveness          20716 non-null  float64
#  15  Valence           20716 non-null  float64
# ...

# %% [markdown]
# <b>Based on the above data, the following observations can be made:</b>
#
# • The dataset has 20718 entries and 28 columns.
#
# • Some columns have missing values like "Danceability" and "Energy", where there are only 20716 out of the total 20718 entries.
#
# • The data types in the DataFrame include integer, float, and object.

# %%
#5

df['Likes'] = df['Likes'].fillna(0)
df['Comments'] = df['Comments'].fillna(0)
df.dropna(inplace=True)

# %%
#6

df.describe()
# Out:
#          Unnamed: 0  Danceability        Energy           Key      Loudness  \
# count  19298.000000  19298.000000  19298.000000  19298.000000  19298.000000
# mean   10426.426365      0.621054      0.635808      5.292103     -7.622436
# std     5984.350044      0.165511      0.213567      3.579583      4.618275
# min        0.000000      0.000000      0.000020      0.000000    -46.251000
# 25%     5238.250000      0.520000      0.510000      2.000000     -8.756000
# 50%    10481.500000      0.639000      0.667000      5.000000     -6.506000
# 75%    15623.750000      0.742000      0.797000      8.000000     -4.922000
# max    20717.000000      0.975000      1.000000     11.000000      0.920000
#
#         Speechiness  Acousticness  Instrumentalness      Liveness  \
# count  19298.000000  19298.000000      19298.000000  19298.000000
# mean       0.094717      0.288219          0.055655      0.191213
# std        0.104731      0.285900          0.193055      0.165146
# ...

# %%
#7

album_types = df['Album_type'].value_counts()
album_types
# Out:
# album          13952
# single          4653
# compilation      693
# Name: Album_type, dtype: int64

# %%
#8

plt.pie(album_types, labels=album_types.index, autopct='%1.1f%%')
plt.title('Album Types')
plt.legend(album_types.index, loc='best')

plt.show()

# %% [markdown]
# <b>From the above pie chart, we can make the following conclusions:</b>
#
# • The majority of the songs in the dataset are albums, accounting for more than 70% of the total songs.
#
# • The second most common type of album is a single, accounting for almost 30% of the total songs, followed by compilation, which is the least common type of album with only 3.6% of the total songs.
#
# • This suggests that albums are the most popular type of release among the artists in the dataset, and that artists in the dataset tend to release albums more frequently than they do singles or compilations.

# %%
#9

# %%
#10

# %%
#11

# %%
#12

views = df.sort_values('Views', ascending=False).head(10)
comments = df.sort_values('Comments', ascending=False).head(10)
likes = df.sort_values('Likes', ascending=False).head(10)

print("\nTop 10 Songs with Most Views:")
display(views[['Track', 'Views']])

print("\nTop 10 Songs with Most Comments:")
display(comments[['Track', 'Comments']])

print("\nTop 10 Songs with Most Likes:")
display(likes[['Track', 'Likes']])
# Out:
# Top 10 Songs with Most Views:
#                                     Track         Views
# 1147                            Despacito  8.079649e+09
# 365                             Despacito  8.079647e+09
# 12452                        Shape of You  5.908398e+09
# 14580  See You Again (feat. Charlie Puth)  5.773798e+09
# 12469  See You Again (feat. Charlie Puth)  5.773797e+09
# 20303                   Wheels on the Bus  4.898831e+09
# 10686      Uptown Funk (feat. Bruno Mars)  4.821016e+09
# 8937                Gangnam Style (강남스타일)  4.679767e+09
# 9569                                Sugar  3.817733e+09
# 13032                                Roar  3.725749e+09
# Top 10 Songs with Most Comments:
#                              Track    Comments
# 14561                     Dynamite  16083138.0
# 14566                       Butter   9131761.0
# 14565  Boy With Luv (feat. Halsey)   6535721.0
# 16030  Boy With Luv (feat. Halsey)   6535719.0
# 8937         Gangnam Style (강남스타일)   5331537.0
# ...

# %%
#13

# %% [markdown]
# <b>Based on the above data, the following observations can be made: </b>
#
# • The song "Despacito" has the highest number of views and likes, followed by See You Again  (feat. Charlie Puth)
#
# • Dynamite and Butter, both by BTS, are the most commented songs, indicating a high level of engagement from their fans.
#
# • In most songs, Western music are one with the most likes and the most views indicative that western's are listened to mostly by casual listeners while Kpop music have the most comments, indicating high engagement of fans from this genre.

# %%
#14

enerdance = df[['Track', 'Energy', 'Danceability']]
enerdance = enerdance.sort_values(by=['Energy', 'Danceability'], ascending=False)

enerdance
# Out:
#                                                    Track    Energy  \
# 20652                              Gentle Piano Melodies  1.000000
# 20582                       Rain and Thunderstorm, Pt. 4  1.000000
# 20585                       Rain and Thunderstorm, Pt. 7  1.000000
# 20581                       Rain and Thunderstorm, Pt. 3  1.000000
# 20587                      Rain and Thunderstorm, Pt. 33  1.000000
# ...                                                  ...       ...
# 13842            Air Conditioner - Loopable with no fade  0.000055
# 15597            Air Conditioner - Loopable with no fade  0.000055
# 15593  Constant Broad Spectrum Noise Loop to Drown Ou...  0.000020
# 11890                                        These Words       NaN
# 13843                          Rain in the Early Morning       NaN
#
#        Danceability
# 20652        0.4370
# 20582        0.2620
# 20585        0.2530
# 20581        0.1600
# 20587        0.1530
# ...             ...
# ...

# %%
#15

music_attributes = df.sort_values('Stream', ascending=False).head(10)

attributes = ['Energy', 'Danceability', 'Acousticness']
data = music_attributes[['Track'] + attributes].set_index('Track')

ax = data.plot(kind='bar', figsize=(10, 6), width=0.8)

ax.set_title('Top 10 Tracks by Stream Count and Attributes')
ax.set_xlabel('Track')
ax.set_ylabel('Value')
ax.legend(attributes)

plt.show()

# %% [markdown]
# <b> From the above bar chart, we can make the following conclusions: </b>
#
# • Danceability are generally taller than the bars for the other attributes, suggesting that the top 10 tracks are generally more danceable than they are energetic or acoustic
#
# • For higher chances of charting in music streams, artists should consider releasing songs that are danceable and energetic.

# %%
#16 

topten = df.groupby('Artist')['Likes'].sum().nlargest(10)
plt.figure(figsize=(12,6))
plt.bar(topten.index, topten.values)
plt.title('Number of Likes per Artist')
plt.xlabel('Likes')
plt.ylabel('Artist')
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# <b> From the above bar chart, we can make the following conclusions: </b>
#
# • BTS and Blackpink are the most favored artists on Spotify, as indicated by the number of likes they have garnered.
#
# • The rest of the other artists are far behind and closely ranked.

# %%
#17

singles = df[df['Album_type'] == 'single'].groupby('Artist').agg({'Views': 'sum', 'Likes': 'sum'}).sort_values(by='Likes', ascending=False).head(10)

singles
# Out:
#                        Views       Likes
# Artist
# BLACKPINK       7.329516e+09  82959030.0
# Wiz Khalifa     6.761550e+09  47790517.0
# Charlie Puth    5.870179e+09  41746947.0
# Jubin Nautiyal  4.525859e+09  39238542.0
# Lil Nas X       3.031660e+09  39103751.0
# Marshmello      2.927575e+09  35843277.0
# Billie Eilish   2.435116e+09  35590580.0
# Bizarrap        1.719856e+09  33922836.0
# Selena Gomez    3.589047e+09  33409887.0
# Ozuna           5.296919e+09  33337259.0

# %%
#18

# %% [markdown]
# <b> Blackpink is the artist with the most viewed and with the most liked single release album, garnering over 7 billion views and 82 million likes followed by Wiz Khalifa and Charlie Puth, the second and the third most viewed and most liked artist. Other top single release artist include Jublin Nautiyal, Lil Nas X, Marshmello, Billie Eilish, and Bizarrap. Selena Gomez is the second last most viewed and most liked artist with over 3 billion views and 33 million likes. A 4 billion views and 49 million likes difference from Blackpink. Selena is followed last by Ozuna, who garnered 5 billion views, on par with the third ranked Charlie Puth but are pushed behind by the likes, which is a little less than Selena's. </b>

# %%
#19

compilations = df[df['Album_type'] == 'compilation'].groupby('Artist').agg({'Views': 'sum', 'Likes': 'sum'}).sort_values(by='Likes', ascending=False).head(10)

compilations
# Out:
#                            Views       Likes
# Artist
# Shakira             3.463816e+09  20327883.0
# Ellie Goulding      2.283748e+09  12418131.0
# Dove Cameron        1.791463e+09  12002533.0
# Earth, Wind & Fire  1.282815e+09   9609744.0
# Idina Menzel        1.876739e+09   9018477.0
# DJ Luian            1.586162e+09   8457661.0
# Mambo Kingz         1.586162e+09   8457653.0
# PSY                 1.539136e+09   8084738.0
# George Michael      1.162993e+09   7481064.0
# Annie Lennox        8.638141e+08   7282923.0

# %% [markdown]
# <b> Shakira is the artist with the most viewed and with the most liked compilation release album, garnering over 3 billion views and 20 million likes followed by Ellie Goulding and Dove Cameron. </b>

# %%
#20

top_channels = df.groupby('Channel')['Views'].sum().nlargest(10)
plt.figure(figsize=(12,6))
plt.bar(top_channels.index, top_channels.values)
plt.title('Top Spotify Channels by Views')
plt.xlabel('Channel')
plt.ylabel('Total Views')
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# <b> From the above bar chart, we can make the following conclusions: </b>
#
# • T-Series, which has accumulated 50 billion views is the most widely watched channel.
#
# • LuisFonsiVEVO, CalvinHarrisVEVO, Macklemore and the remaining channels within the top 10 are far behind with T-series but are closely ranked with each other.
